# %%
import pandas as  pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/User/Desktop/sample_1.csv")

# %%
df
# Out:
#               연구번호      입실일자    입실시각    검사코드  \
# 0       1219300234  20210220  1350.0  ZF0156
# 1       1219300234  20210220  1350.0  ZF0016
# 2       1219300234  20210220  1350.0  ZF0155
# 3       1219300234  20210220  1350.0  BB0007
# 4       1219300234  20210220  1350.0  ZF0012
# ...            ...       ...     ...     ...
# 799995  1169043575  20200519  1800.0  ZF0157
# 799996  1169043575  20200519  1800.0  BC0202
# 799997  1169043575  20200519  1800.0  ZF0014
# 799998  1169043575  20200519  1800.0  ZF0016
# 799999  1169043575  20200519  1800.0  BB0074
#
#                                         검사코드NM  검사결과값(숫자)  \
# 0               ABGA coding (Des),Artery blood      342.0
# 1                Bicarbonate (Qn),Artery blood       27.5
# 2       ABGA interpretation (Des),Artery blood        NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8
# 4              O2 saturation (Qn),Artery blood       98.3
# ...                                        ...        ...
# ...

# %%
df = df.drop('성별코드NM', axis=1)

# %%
df
# Out:
#               연구번호      입실일자          입실시각    검사코드  \
# 0       1219300234  20210220  13:50.0:50.0  ZF0156
# 1       1219300234  20210220  13:50.0:50.0  ZF0016
# 2       1219300234  20210220  13:50.0:50.0  ZF0155
# 3       1219300234  20210220  13:50.0:50.0  BB0007
# 4       1219300234  20210220  13:50.0:50.0  ZF0012
# ...            ...       ...           ...     ...
# 799995  1169043575  20200519  18:00.0:00.0  ZF0157
# 799996  1169043575  20200519  18:00.0:00.0  BC0202
# 799997  1169043575  20200519  18:00.0:00.0  ZF0014
# 799998  1169043575  20200519  18:00.0:00.0  ZF0016
# 799999  1169043575  20200519  18:00.0:00.0  BB0074
#
#                                         검사코드NM  검사결과값(숫자)  \
# 0               ABGA coding (Des),Artery blood      342.0
# 1                Bicarbonate (Qn),Artery blood       27.5
# 2       ABGA interpretation (Des),Artery blood        NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8
# ...

# %%
df.dropna(subset=['검사결과값(숫자)'], inplace=True)
df.dropna(subset=['검사결과값(표시)'], inplace=True)

# %%
df
# Out:
#               연구번호      입실일자          입실시각    검사코드  \
# 0       1219300234  20210220  13:50.0:50.0  ZF0156
# 1       1219300234  20210220  13:50.0:50.0  ZF0016
# 3       1219300234  20210220  13:50.0:50.0  BB0007
# 4       1219300234  20210220  13:50.0:50.0  ZF0012
# 5       1219300234  20210220  13:50.0:50.0  ZF0012
# ...            ...       ...           ...     ...
# 799993  1169043575  20200519  18:00.0:00.0  BC0202
# 799996  1169043575  20200519  18:00.0:00.0  BC0202
# 799997  1169043575  20200519  18:00.0:00.0  ZF0014
# 799998  1169043575  20200519  18:00.0:00.0  ZF0016
# 799999  1169043575  20200519  18:00.0:00.0  BB0074
#
#                                  검사코드NM  검사결과값(숫자) 검사결과값(표시)  기준치상한값  기준치하한값  \
# 0        ABGA coding (Des),Artery blood      342.0       342     NaN     NaN
# 1         Bicarbonate (Qn),Artery blood       27.5      27.5    29.0    23.0
# 3             pO2 (Qn)[EM],Artery blood      117.8     117.8   108.0    83.0
# ...

# %%
df2 = pd.read_csv("C:/Users/User/Desktop/~$trans_1.csv")

# %%
df
# Out:
#               연구번호      입실일자          입실시각    검사코드  \
# 0       1219300234  20210220  13:50.0:50.0  ZF0156
# 1       1219300234  20210220  13:50.0:50.0  ZF0016
# 3       1219300234  20210220  13:50.0:50.0  BB0007
# 4       1219300234  20210220  13:50.0:50.0  ZF0012
# 5       1219300234  20210220  13:50.0:50.0  ZF0012
# ...            ...       ...           ...     ...
# 799993  1169043575  20200519  18:00.0:00.0  BC0202
# 799996  1169043575  20200519  18:00.0:00.0  BC0202
# 799997  1169043575  20200519  18:00.0:00.0  ZF0014
# 799998  1169043575  20200519  18:00.0:00.0  ZF0016
# 799999  1169043575  20200519  18:00.0:00.0  BB0074
#
#                                  검사코드NM  검사결과값(숫자) 검사결과값(표시)  기준치상한값  기준치하한값  \
# 0        ABGA coding (Des),Artery blood      342.0       342     NaN     NaN
# 1         Bicarbonate (Qn),Artery blood       27.5      27.5    29.0    23.0
# 3             pO2 (Qn)[EM],Artery blood      117.8     117.8   108.0    83.0
# ...

# %%
df2 = df.drop('접수시각', axis=1)

# %%
df2 = df.drop('접수일자', axis=1)

# %%
df2
# Out:
#               연구번호      입실일자          입실시각    검사코드  \
# 0       1219300234  20210220  13:50.0:50.0  ZF0156
# 1       1219300234  20210220  13:50.0:50.0  ZF0016
# 3       1219300234  20210220  13:50.0:50.0  BB0007
# 4       1219300234  20210220  13:50.0:50.0  ZF0012
# 5       1219300234  20210220  13:50.0:50.0  ZF0012
# ...            ...       ...           ...     ...
# 799993  1169043575  20200519  18:00.0:00.0  BC0202
# 799996  1169043575  20200519  18:00.0:00.0  BC0202
# 799997  1169043575  20200519  18:00.0:00.0  ZF0014
# 799998  1169043575  20200519  18:00.0:00.0  ZF0016
# 799999  1169043575  20200519  18:00.0:00.0  BB0074
#
#                                  검사코드NM  검사결과값(숫자) 검사결과값(표시)  기준치상한값  기준치하한값  \
# 0        ABGA coding (Des),Artery blood      342.0       342     NaN     NaN
# 1         Bicarbonate (Qn),Artery blood       27.5      27.5    29.0    23.0
# 3             pO2 (Qn)[EM],Artery blood      117.8     117.8   108.0    83.0
# ...

# %%
df2 = df2[df2['환자생년월'].isin([193909, 193911])]

# %%
df2
# Out:
#               연구번호      입실일자          입실시각    검사코드  \
# 0       1219300234  20210220  13:50.0:50.0  ZF0156
# 1       1219300234  20210220  13:50.0:50.0  ZF0016
# 3       1219300234  20210220  13:50.0:50.0  BB0007
# 4       1219300234  20210220  13:50.0:50.0  ZF0012
# 5       1219300234  20210220  13:50.0:50.0  ZF0012
# ...            ...       ...           ...     ...
# 581939  1186398406  20200702    23:0.0:0.0  ZF0012
# 581940  1186398406  20200702    23:0.0:0.0  BB0005
# 581941  1186398406  20200702    23:0.0:0.0  BC0202
# 581942  1186398406  20200702    23:0.0:0.0  ZF0012
# 581943  1186398406  20200702    23:0.0:0.0  BC0202
#
#                                  검사코드NM  검사결과값(숫자) 검사결과값(표시)  기준치상한값  기준치하한값  \
# 0        ABGA coding (Des),Artery blood    342.000       342     NaN     NaN
# 1         Bicarbonate (Qn),Artery blood     27.500      27.5   29.00   23.00
# 3             pO2 (Qn)[EM],Artery blood    117.800     117.8  108.00   83.00
# ...
