# %%
A = "안녕하세요 지금은 데이터 전처리 수업 시간입니다."

# %%
A = "안녕하세요 지금은 데이터 전처리 수업 시간입니다."

# %%
A = "안녕하세요 지금은 데이터 전처리 수업 시간입니다."

# %%
A[0:4]
# Out:
# '안녕하세'

# %%
A[0:9]
# Out:
# '안녕하세요 지금은'

# %%
A[-6:]
# Out:
# '시간입니다.'

# %%
A[-9:-7]
# Out:
# '수업'

# %%
A="I am {}"

# %%
B="jihye"

# %%
A.format(B)
# Out:
# 'I am jihye'

# %%
print(("{}, {}").format(A,B))
# Out:
# I am {}, jihye

# %%
print(("{:.2f}, {:.3f}").format(3.1415,3.1415))
# Out:
# 3.14, 3.142

# %%
url = "https://www.youtube.com/"
url = url.replace("youtube", "naver")
print(url)
# Out:
# https://www.naver.com/

# %%
A = [10,20,30,40,50,60,70,80,90]

# %%
A [0:4]
# Out:
# [10, 20, 30, 40]

# %%
A = ["독고영재, 50", "김철수, 30"]

# %%
A[0]
# Out:
# '독고영재, 50'

# %%
type(A)
# Out:
# list

# %%
type(A[0])
# Out:
# str

# %%
A[0][:4]
# Out:
# '독고영재'

# %%
A[1][-2:]
# Out:
# '30'

# %%
a=["독고영재, 50","김철수, 30"]
b=["김철수, 30", "김영희, 25"]

# %%
a[0][:a[0].index(",")]
# Out:
# '독고영재'

# %%
b[1][:b[1].index(",")]
# Out:
# '김영희'

# %%
a = ["hi", 10, "80", "김철수",50, 50.6]

# %%
a.append(100)

# %%
a
# Out:
# ['hi', 10, '80', '김철수', 50, 50.6, 1, 100]

# %%
a.pop(1) #제거하고 싶든 값의 위치
# Out:
# 10

# %%
a
# Out:
# ['hi', '80', '김철수', 50, 50.6, 1, 100]

# %%
a.index(50)
# Out:
# 3

# %%
a.pop(3)
# Out:
# 50

# %%
a
# Out:
# ['hi', '80', '김철수', 50.6, 1, 100]

# %%
import numpy as np
a=np.array([1,2,3,4])
a=np.append(a,[4,5])
a=np.insert(a,1,[7,8])

# %%
a=np.array([1,2,3,4,5])
a=np.delete(a,[1,3])

# %%
a=a[a<=4]

# %%
array1 = np.array([[1,2],[3,4]])
array2 = np.array([[5,6],[7,8]])
merged_array = np.vstack((array1, array2))
print(merged_array) #수직
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
array1 = np.array([[1,2],[3,4]])
array2 = np.array([[5,6],[7,8]])
merged_array = np.hstack((array1, array2))
print(merged_array) #수평
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
A={1:"김철수", 20:"박영희"}

# %%
A[1]
# Out:
# '김철수'

# %%
A[20]
# Out:
# '박영희'

# %%
A.get(1)
# Out:
# '김철수'

# %%
A[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 A[3]
#
# KeyError: 3

# %%
A.get(3) #none 값 출력

# %%
B={"1-A":"김철수", "20-b":"박영희"}

# %%
B["2-A"]="영희"

# %%
del B["20-b"]

# %%
A = {
    "1-A" : [1,2,3,4,5],
    "20-B" : ["A","B","C","D","E"]
}

# %%
A = [10,20,30,[1,2,3]]

# %%
print(A[3])
# Out:
# {1, 2, 3}

# %%
math_score = [20,30,40,50,60]
english_score = [50,70,50,60,90]

# %%
url = "https://www.youtube.com/"
url = url.replace("youtube", "naver")
print(url)
# Out:
# https://www.naver.com/

# %%
math_avg = sum(math_score)/len(math_score)
english_avg = sum(english_score)/len(math_score)
print("수학 점수 평균:", math_avg)
print("영어 점수 평균:", english_avg)
# Out:
# 수학 점수 평균: 40.0
# 영어 점수 평균: 64.0

# %%
list = [1,2,100,4,5,900]
list.remove(100)
list.remove(900)

# %%
list
# Out:
# [1, 2, 4, 5]

# %%
score ={
    "math" : math_score,
    "english" : english_score
}

# %%
score = {
    "math" : [20,30,40,50,60],
    "english" : [50,70,50,60,90]
}

A = score["math"][0]+score["english"][2]
print(A)
# Out:
# 70
