# %%
import pandas as  pd
import numpy as np

# %%
data = {
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'city':['New York','Paris','London']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      city
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
df = pd.read_csv("C:/Users/User/Desktop/a/data_06.csv", header=0,encoding='cp949')

# %%
df
# Out:
#    국어  영어  수학  합계
# 0  25  34  87  146
# 1  35  35  65  135
# 2  36  88  56  180
# 3  57  45  23  125
# 4  67  45  77  189
# 5  89  67  45  201
# 6  24  56  66  146

# %%
df=pd.read_csv("C:/Users/User/Desktop/a/국영수.csv", encoding='utf-8')

# %%
df
# Out:
#    국어  영어  수학 체육
# 0  50  88  21  상
# 1  41  87  54  중
# 2  85  65  84  상
# 3  61  85  13  중
# 4  54  41  21  하
# 5  84  47  87  하
# 6  77  98  65  상
# 7  87  58  54  중
# 8  54  22  78  히

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['국어', '영어', '수학', '체육'], dtype='object')

# %%
df.dtypes
# Out:
# 국어     int64
# 영어     int64
# 수학     int64
# 체육    object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    국어  영어  수학 체육
# 0  50  88  21  상
# 1  41  87  54  중
# 2  85  65  84  상
# 3  61  85  13  중
# 4  54  41  21  하
# 5  84  47  87  하
# 6  77  98  65  상
# 7  87  58  54  중
# 8  54  22  78  히>

# %%
df.head()
# Out:
#    국어  영어  수학 체육
# 0  50  88  21  상
# 1  41  87  54  중
# 2  85  65  84  상
# 3  61  85  13  중
# 4  54  41  21  하

# %%
df.tail()
# Out:
#    국어  영어  수학 체육
# 4  54  41  21  하
# 5  84  47  87  하
# 6  77  98  65  상
# 7  87  58  54  중
# 8  54  22  78  히

# %%
df.isnull().sum()
# Out:
# 국어    0
# 영어    0
# 수학    0
# 체육    0
# dtype: int64

# %%
df['column'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df['column'].value_counts()
#
# ...

# %%
df['column'].unique()
df['column'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df['column'].unlque()
#
# ...

# %%
df["합계"]=df["국어"]+df["영어"]
print(df)
# Out:
#    국어  영어  수학 체육   합계
# 0  50  88  21  상  138
# 1  41  87  54  중  128
# 2  85  65  84  상  150
# 3  61  85  13  중  146
# 4  54  41  21  하   95
# 5  84  47  87  하  131
# 6  77  98  65  상  175
# 7  87  58  54  중  145
# 8  54  22  78  히   76

# %%
columns = ['column_a', 'column_b','column_c']
selected_columns = df[columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 columns = ['column_a', 'column_b','column_c']
# ----> 2 selected_columns = df[columns]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
# ...

# %%
df=df.drop(['국어'], axis=1)

# %%
data = {
    'A':[1,2,3,4],
    'B':[4.1,3.5,2.1,5.7],
    'c':['one', 'two','three','four']
}
df =pd.DataFrame(data)

# %%
df['A']=df['A'].astype(float)
df['B']=df['B'].astype(int)

# %%
df
# Out:
#      A    B      c
# 0  1.0  4.1    one
# 1  2.0  3.5    two
# 2  3.0  2.1  three
# 3  4.0  5.7   four

# %%
df.df.rename(columns={'국영수':'123'})

# %%
data = {
    'Numeric1':[1,np.nan,3,4],
    'Numeric2':[5,6,np.nan,8.2],
    'Category':['dog',np.nan,'cat','dog']
    
}
df = pd.DataFrame(data)

A=df.select_dtypes(include=["number"]).columns
df[A]

B=df.select_dtypes(include=['object','category']).columns
df[B]
# Out:
#   Category
# 0      dog
# 1      NaN
# 2      cat
# 3      dog

# %%
df[A].fillna(df[A].median())
df[A].fillna(df[A].mean())
# Out:
#    Numeric1  Numeric2
# 0  1.000000       5.0
# 1  2.666667       6.0
# 2  3.000000       6.4
# 3  4.000000       8.2

# %%
df1 = pd.DataFrame({
    'a':['a0','a1','a2','a3'],
    'b':['b0','b1','b2','b3'],
    'c':['c0','c1','c2','c3']
})

df2 = pd.DataFrame({
    'a':['a2','a3','a4','a5'],
    'b':['b2','b3','b4','b5'],
    'c':['c2','c3','c4','c5'],
    'd':['d2','d3','d4','d5'],
    
})

# %%
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2
# Out:
#     a   b   c   d
# 0  a2  b2  c2  d2
# 1  a3  b3  c3  d3
# 2  a4  b4  c4  d4
# 3  a5  b5  c5  d5

# %%
pd.concat([df1,df2], axis=0)
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 0  a2  b2  c2   d2
# 1  a3  b3  c3   d3
# 2  a4  b4  c4   d4
# 3  a5  b5  c5   d5

# %%
pd.concat([df1,df2], axis=1)
# Out:
#     a   b   c   a   b   c   d
# 0  a0  b0  c0  a2  b2  c2  d2
# 1  a1  b1  c1  a3  b3  c3  d3
# 2  a2  b2  c2  a4  b4  c4  d4
# 3  a3  b3  c3  a5  b5  c5  d5

# %%
data = {
    'Numeric1':[1,np.nan,3,4],
    'Numeric2':[5,6,np.nan,8.2],
    'Category':['dog',np.nan,'cat','dog']
    
}
df = pd.DataFrame(data)

# %%
df[(df['Numeric2']>=6)&(df['Numeric2']<=10)]
# Out:
#    Numeric1  Numeric2 Category
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog

# %%
df[(df['Numeric2']>=6)|(df['Numeric2']<=10)]
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog
